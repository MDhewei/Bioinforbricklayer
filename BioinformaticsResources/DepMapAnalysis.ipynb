# %%
# CRISPRGeneEffect.csv
# Model.csv
# OmicsExpressionProteinCodingGenesTPMLogp1.csv
# OmicsSomaticMutations.csv
# OmicsCNGene.csv

# %%
import pandas as pd

### CRISPR knockout screen across 1000+ cell lines

df_crispr = pd.read_csv('CRISPRGeneEffect.csv',index_col=0)

# %%
df_crispr
# Out:
#             A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# ACH-000004  0.014633     -0.032777 -0.151299       -0.071388
# ACH-000005 -0.261566      0.174833  0.106526        0.135635
# ACH-000007 -0.028717     -0.117017  0.030971        0.083795
# ACH-000009  0.000225     -0.283124  0.051248        0.120321
# ACH-000011  0.095791     -0.099622  0.022204        0.199771
# ...              ...           ...       ...             ...
# ACH-002296 -0.073879      0.046252 -0.077086        0.028623
# ACH-002297  0.084735     -0.249753  0.045093        0.070714
# ACH-002298 -0.172365     -0.112164  0.055771       -0.017571
# ACH-002304 -0.033065      0.171028 -0.044622        0.185127
# ACH-002305  0.076307     -0.241877  0.165187       -0.088436
#
#             A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# ACH-000004          0.046511       -0.162850       0.290698    -0.240991
# ACH-000005         -0.076753       -0.278640       0.239279    -0.325967
# ACH-000007          0.032668       -0.035709       0.012355    -0.192436
# ACH-000009          0.022834       -0.077522       0.028013    -0.190495
# ACH-000011         -0.048126       -0.290812      -0.013277    -0.095840
# ...                      ...             ...            ...          ...
# ACH-002296         -0.000662        0.003801       0.023230    -1.143038
# ACH-002297         -0.194074       -0.038278      -0.029772    -0.743310
# ACH-002298         -0.010154       -0.069917      -0.092145    -0.135460
# ACH-002304          0.063611       -0.047573       0.118359    -0.571989
# ACH-002305          0.031024        0.115397      -0.065532    -0.587833
#
#             AACS (65985)  AADAC (13)  ...  ZWILCH (55055)  ZWINT (11130)  \
# ACH-000004      0.176710    0.159418  ...       -0.188857      -0.389649
# ACH-000005     -0.116848    0.022227  ...       -0.195492      -0.360578
# ACH-000007     -0.077174    0.164877  ...       -0.200402      -0.382707
# ACH-000009      0.031589    0.043242  ...       -0.179775      -0.285412
# ACH-000011      0.090307    0.029379  ...       -0.671885      -0.558008
# ...                  ...         ...  ...             ...            ...
# ACH-002296      0.004579    0.115898  ...        0.135984      -0.666816
# ACH-002297      0.081368    0.155969  ...       -0.407122      -0.473605
# ACH-002298      0.008202   -0.132641  ...       -0.270696      -0.383323
# ACH-002304     -0.101702    0.263272  ...        0.106406      -0.300325
# ACH-002305      0.080505   -0.079979  ...       -0.308187      -0.824144
#
#             ZXDA (7789)  ZXDB (158586)  ZXDC (79364)  ZYG11A (440590)  \
# ACH-000004     0.112266      -0.002883      0.155729         0.077283
# ACH-000005    -0.126277      -0.059287      0.080543        -0.161894
# ACH-000007     0.006843       0.199553      0.064425        -0.031683
# ACH-000009    -0.029599       0.227176     -0.097506        -0.136990
# ACH-000011     0.020997       0.011011      0.206251         0.086453
# ...                 ...            ...           ...              ...
# ACH-002296     0.015930      -0.000437      0.157030        -0.054452
# ACH-002297    -0.000171       0.153230     -0.066343         0.029340
# ACH-002298     0.101514       0.101316      0.110317        -0.006500
# ACH-002304    -0.034307      -0.176315     -0.054927        -0.079415
# ACH-002305    -0.183761       0.006969      0.215163         0.010098
#
#             ZYG11B (79699)  ZYX (7791)  ZZEF1 (23140)  ZZZ3 (26009)
# ACH-000004       -0.294451    0.143978       0.197069     -0.003338
# ACH-000005       -0.070230   -0.006275       0.002458      0.014259
# ACH-000007       -0.291406   -0.065945      -0.260946     -0.329018
# ACH-000009       -0.421927    0.050002      -0.107675     -0.249623
# ACH-000011       -0.166360   -0.055975      -0.159886     -0.311232
# ...                    ...         ...            ...           ...
# ACH-002296       -0.260831    0.064285       0.041468     -0.428699
# ACH-002297       -0.120501   -0.058169      -0.179429     -0.172884
# ACH-002298       -0.158971   -0.114161       0.128512     -0.267323
# ACH-002304       -0.130105    0.133510      -0.126235     -0.211761
# ACH-002305       -0.107611   -0.108798       0.001063     -0.291455
#
# [1078 rows x 17453 columns]

# %%
df_cell = pd.read_csv('Model.csv')

# %%
df_cell
# Out:
#          ModelID  PatientID   CellLineName StrippedCellLineName   Age  \
# 0     ACH-000001  PT-gj46wT    NIH:OVCAR-3            NIHOVCAR3  60.0
# 1     ACH-000002  PT-5qa3uk          HL-60                 HL60  36.0
# 2     ACH-000003  PT-puKIyc          CACO2                CACO2  72.0
# 3     ACH-000004  PT-q4K2cp            HEL                  HEL  30.0
# 4     ACH-000005  PT-q4K2cp     HEL 92.1.7              HEL9217  30.0
# ...          ...        ...            ...                  ...   ...
# 1821  ACH-002785  PT-6sPicj    NCC-LMS1-C1            NCCLMS1C1  42.0
# 1822  ACH-002800  PT-WTpRkW  NCC-MPNST2-C1          NCCMPNST2C1  54.0
# 1823  ACH-002834  PT-EcUHFc        PSS131R              PSS131R   NaN
# 1824  ACH-002847  PT-AFnHpd   YUHOIN 06-50           YUHOIN0650  59.0
# 1825  ACH-002926  PT-vu5jnE          UPMD1                UPMD1   NaN
#
#         SourceType SangerModelID       RRID DepmapModelType GrowthPattern  \
# 0       Commercial     SIDM00105  CVCL_0465           HGSOC      Adherent
# 1       Commercial     SIDM00829  CVCL_0002             AML    Suspension
# 2       Commercial     SIDM00891  CVCL_0025            COAD      Adherent
# 3       Commercial     SIDM00594  CVCL_0001             AML    Suspension
# 4       Commercial     SIDM00593  CVCL_2481             AML       Unknown
# ...            ...           ...        ...             ...           ...
# 1821  Academic lab           NaN  CVCL_LK56             LMS           NaN
# 1822  Academic lab           NaN  CVCL_YU13           MPNST           NaN
# 1823  Academic lab           NaN        NaN              OS           NaN
# 1824  Academic lab           NaN  CVCL_J521             MEL           NaN
# 1825           NaN           NaN  CVCL_C297              UM           NaN
#
#       ...                                       SourceDetail CatalogNumber  \
# 0     ...                                               ATCC           NaN
# 1     ...                                               ATCC           NaN
# 2     ...                                               ATCC           NaN
# 3     ...                                               DSMZ           NaN
# 4     ...                                               ATCC           NaN
# ...   ...                                                ...           ...
# 1821  ...               Kondo (National Cancer Center Tokyo)           NaN
# 1822  ...               Kondo (National Cancer Center Tokyo)           NaN
# 1823  ...  Alejandro Sweet-Cordero (UCSF); passed to us f...           NaN
# 1824  ...                                     Halaban (Yale)           NaN
# 1825  ...              QIMRB Berghofer (via CRUK Manchester)           NaN
#
#                                         CCLEName  COSMICID  \
# 0                                NIHOVCAR3_OVARY  905933.0
# 1        HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  905938.0
# 2                          CACO2_LARGE_INTESTINE       NaN
# 3         HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  907053.0
# 4     HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       NaN
# ...                                          ...       ...
# 1821                                         NaN       NaN
# 1822                                         NaN       NaN
# 1823                        PSS131R_Osteosarcoma       NaN
# 1824                    YUHOIN0650_Melanoma_Skin       NaN
# 1825                          UPMD1_Melanoma_Eye       NaN
#
#                                      PublicComments  WTSIMasterCellID  \
# 0                                               NaN            2201.0
# 1                                               NaN              55.0
# 2                                               NaN               NaN
# 3                                               NaN             783.0
# 4                                               NaN               NaN
# ...                                             ...               ...
# 1821  Patient-derived model; Matches NCC-LMS1-X3-C1               NaN
# 1822                          Patient-derived model               NaN
# 1823                                            NaN               NaN
# 1824                                            NaN               NaN
# 1825                                            NaN               NaN
#
#      OncotreeCode                          OncotreeSubtype  \
# 0           HGSOC         High-Grade Serous Ovarian Cancer
# 1             AML                   Acute Myeloid Leukemia
# 2            COAD                     Colon Adenocarcinoma
# 3             AML                   Acute Myeloid Leukemia
# 4             AML                   Acute Myeloid Leukemia
# ...           ...                                      ...
# 1821          LMS                           Leiomyosarcoma
# 1822        MPNST  Malignant Peripheral Nerve Sheath Tumor
# 1823           OS                             Osteosarcoma
# 1824          MEL                                 Melanoma
# 1825           UM                           Uveal Melanoma
#
#          OncotreePrimaryDisease            OncotreeLineage
# 0      Ovarian Epithelial Tumor       Ovary/Fallopian Tube
# 1        Acute Myeloid Leukemia                    Myeloid
# 2     Colorectal Adenocarcinoma                      Bowel
# 3        Acute Myeloid Leukemia                    Myeloid
# 4        Acute Myeloid Leukemia                    Myeloid
# ...                         ...                        ...
# 1821             Leiomyosarcoma                Soft Tissue
# 1822         Nerve Sheath Tumor  Peripheral Nervous System
# 1823               Osteosarcoma                       Bone
# 1824                   Melanoma                       Skin
# 1825            Ocular Melanoma                        Eye
#
# [1826 rows x 24 columns]

# %%
import seaborn as sns

sns.distplot(df_crispr.loc['ACH-000004',:])
# Out:
# /Users/whe3/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ACH-000004', ylabel='Density'>

# %%
### Gene expression (RNAseq) in different cell lines
### Gene expression TPM values of the protein coding genes uing log2 transformation 
### with a pseudo-count of 1; log2(TPM+1).

# 1.Count the number of reads mapped to each gene (raw counts).
# 2.Normalize the raw counts by the gene length (usually measured in kilobases, or kb) to account for differences in gene lengths. This step produces the Reads Per Kilobase (RPK) values.
# 3.Sum the RPK values for all genes to get the total RPK.
# 4.Divide each gene's RPK value by the total RPK and multiply by 1,000,000 to obtain the TPM values.

df_exp = pd.read_csv('OmicsExpressionProteinCodingGenesTPMLogp1.csv',index_col=0)

# %%
df_exp
# Out:
#             TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# ACH-001113       4.331992      0.000000     7.364660       2.792855
# ACH-001289       4.567424      0.584963     7.106641       2.543496
# ACH-001339       3.150560      0.000000     7.379118       2.333424
# ACH-001538       5.085340      0.000000     7.154211       2.545968
# ACH-000242       6.729417      0.000000     6.537917       2.456806
# ...                   ...           ...          ...            ...
# ACH-000285       0.056584      0.000000     6.604368       3.266037
# ACH-002669       3.111031      0.000000     7.031329       1.541019
# ACH-001858       4.390943      0.000000     7.013239       1.887525
# ACH-001997       5.057450      0.000000     7.815191       2.538538
# ACH-000052       4.249445      0.000000     6.175724       2.319040
#
#             C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  \
# ACH-001113          4.471187    0.028569    1.226509      3.044394
# ACH-001289          3.504620    0.000000    0.189034      3.813525
# ACH-001339          4.228049    0.056584    1.310340      6.687201
# ACH-001538          3.084064    0.000000    5.868390      6.165309
# ACH-000242          3.867896    0.799087    7.208478      5.570159
# ...                      ...         ...         ...           ...
# ACH-000285          4.973152    0.411426    0.097611      0.704872
# ACH-002669          3.664483    0.014355    3.624101      6.805421
# ACH-001858          3.252476    0.028569    3.286881      6.902194
# ACH-001997          3.893362    0.028569    4.079805      6.971659
# ACH-000052          3.825786    0.189034    1.321928      3.538538
#
#             GCLC (2729)  NFYA (4800)  ...  H3C2 (8358)  H3C3 (8352)  \
# ACH-001113     6.500005     4.739848  ...     2.689299     0.189034
# ACH-001289     4.221877     3.481557  ...     1.286881     1.049631
# ACH-001339     3.682573     3.273516  ...     0.594549     1.097611
# ACH-001538     4.489928     3.956986  ...     0.214125     0.632268
# ACH-000242     7.127117     4.568032  ...     1.117695     2.358959
# ...                 ...          ...  ...          ...          ...
# ACH-000285     4.829850     5.178715  ...     2.229588     0.084064
# ACH-002669     4.472488     4.397118  ...     0.189034     0.400538
# ACH-001858     5.410748     3.401903  ...     1.097611     0.400538
# ACH-001997     4.469886     3.463361  ...     0.831877     0.847997
# ACH-000052     3.945795     4.469886  ...     1.244887     1.207893
#
#             AC098582.1 (8916)  DUS4L-BCAP29 (115253422)  \
# ACH-001113           0.201634                  2.130931
# ACH-001289           0.321928                  1.464668
# ACH-001339           0.831877                  2.946731
# ACH-001538           0.298658                  1.641546
# ACH-000242           0.084064                  1.910733
# ...                       ...                       ...
# ACH-000285           1.310340                  3.039138
# ACH-002669           0.356144                  1.327687
# ACH-001858           0.613532                  1.992768
# ACH-001997           1.292782                  2.153805
# ACH-000052           0.000000                  1.956057
#
#             C8orf44-SGK3 (100533105)  ELOA3B (728929)  NPBWR1 (2831)  \
# ACH-001113                  0.555816         0.000000       0.275007
# ACH-001289                  0.632268         0.000000       0.014355
# ACH-001339                  0.475085         0.000000       0.084064
# ACH-001538                  0.443607         0.000000       0.028569
# ACH-000242                  0.000000         0.000000       0.464668
# ...                              ...              ...            ...
# ACH-000285                  0.344828         0.000000       0.000000
# ACH-002669                  0.000000         0.000000       0.014355
# ACH-001858                  0.704872         0.000000       1.464668
# ACH-001997                  0.687061         0.000000       0.000000
# ACH-000052                  0.575312         0.042644       0.000000
#
#             ELOA3D (100506888)  ELOA3 (162699)  CDR1 (1038)
# ACH-001113                 0.0        0.000000     0.000000
# ACH-001289                 0.0        0.000000     0.000000
# ACH-001339                 0.0        0.000000     0.042644
# ACH-001538                 0.0        0.000000     0.000000
# ACH-000242                 0.0        0.000000     0.000000
# ...                        ...             ...          ...
# ACH-000285                 0.0        0.475085     0.042644
# ACH-002669                 0.0        0.000000     0.000000
# ACH-001858                 0.0        0.000000     0.526069
# ACH-001997                 0.0        0.000000     0.000000
# ACH-000052                 0.0        0.176323     0.056584
#
# [1408 rows x 19193 columns]

# %%
### Gene mutation status in different cell lines

df_mut = pd.read_csv('OmicsSomaticMutations.csv')
# Out:
# /Users/whe3/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (32,40,48,49,50,51,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_mut
# Out:
#                  Chrom        Pos Ref Alt     AF  RefCount  AltCount   GT  \
# C1QTNF12_p.L261V  chr1    1242864  GC  CT  0.310        19         8  0/1
# CASZ1_p.V1110A    chr1   10647969   A   G  0.400        29        19  0|1
# CASZ1_p.T1067T    chr1   10648097   T   G  0.349        21        10  0/1
# PRAMEF13_p.T257I  chr1   13198424   G   A  0.833         0         4  0/1
# PRAMEF18_p.L218P  chr1   13225068   A   G  0.396        34        24  0/1
# ...                ...        ...  ..  ..    ...       ...       ...  ...
# F9_p.R449W        chrX  139562030   C   T  0.962         1        53  1|1
# MAGEC3_p.V477V    chrX  141897189   C   G  0.951         4       104  1|1
# SPANXN3_p.P31S    chrX  143509150   G   A  0.985         0        72  1|1
# MT-ND5_p.T439A    chrM      13651   A   G  0.800         0         3  0/1
# MT-CYB_p.R80H     chrM      14985   G   A  0.571         2         3  0/1
#
#                           PS VariantType  ... Funseq2Score PharmgkbID DidaID  \
# C1QTNF12_p.L261V         NaN         DNP  ...          NaN        NaN    NaN
# CASZ1_p.V1110A    10647969.0         SNP  ...          3.0        NaN    NaN
# CASZ1_p.T1067T           NaN         SNP  ...          0.0        NaN    NaN
# PRAMEF13_p.T257I         NaN         SNP  ...          NaN        NaN    NaN
# PRAMEF18_p.L218P         NaN         SNP  ...          0.0        NaN    NaN
# ...                      ...         ...  ...          ...        ...    ...
# F9_p.R449W               NaN         SNP  ...          1.0        NaN    NaN
# MAGEC3_p.V477V           NaN         SNP  ...          0.0        NaN    NaN
# SPANXN3_p.P31S           NaN         SNP  ...          1.0        NaN    NaN
# MT-ND5_p.T439A           NaN         SNP  ...          NaN        NaN    NaN
# MT-CYB_p.R80H            NaN         SNP  ...          NaN        NaN    NaN
#
#                  DidaName GwasDisease GwasPmID GTexGene   DepMap_ID  \
# C1QTNF12_p.L261V      NaN         NaN      NaN      NaN  ACH-000839
# CASZ1_p.V1110A        NaN         NaN      NaN      NaN  ACH-000839
# CASZ1_p.T1067T        NaN         NaN      NaN      NaN  ACH-000839
# PRAMEF13_p.T257I      NaN         NaN      NaN      NaN  ACH-000839
# PRAMEF18_p.L218P      NaN         NaN      NaN      NaN  ACH-000839
# ...                   ...         ...      ...      ...         ...
# F9_p.R449W            NaN         NaN      NaN      NaN  ACH-000840
# MAGEC3_p.V477V        NaN         NaN      NaN      NaN  ACH-000840
# SPANXN3_p.P31S        NaN         NaN      NaN      NaN  ACH-000840
# MT-ND5_p.T439A        NaN         NaN      NaN      NaN  ACH-000840
# MT-CYB_p.R80H         NaN         NaN      NaN      NaN  ACH-000840
#
#                  EntrezGeneID      MutationType
# C1QTNF12_p.L261V     388581.0  C1QTNF12_p.L261V
# CASZ1_p.V1110A        54897.0    CASZ1_p.V1110A
# CASZ1_p.T1067T        54897.0    CASZ1_p.T1067T
# PRAMEF13_p.T257I     400736.0  PRAMEF13_p.T257I
# PRAMEF18_p.L218P     391003.0  PRAMEF18_p.L218P
# ...                       ...               ...
# F9_p.R449W             2158.0        F9_p.R449W
# MAGEC3_p.V477V       139081.0    MAGEC3_p.V477V
# SPANXN3_p.P31S       139067.0    SPANXN3_p.P31S
# MT-ND5_p.T439A         4540.0    MT-ND5_p.T439A
# MT-CYB_p.R80H          4519.0     MT-CYB_p.R80H
#
# [1387895 rows x 57 columns]

# %%
df_mut['MutationType'] = df_mut['HugoSymbol']+'_'+df_mut['ProteinChange']

# %%
df_mut[df_mut['MutationType']=='KRAS_p.G12D']
# Out:
#              Chrom       Pos Ref Alt     AF  RefCount  AltCount   GT  PS  \
# KRAS_p.G12D  chr12  25245350   C   T  0.278        26         9  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.488        21        20  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.375        20        11  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.525        34        37  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.976         0        39  1|1 NaN
# ...            ...       ...  ..  ..    ...       ...       ...  ...  ..
# KRAS_p.G12D  chr12  25245350   C   T  0.383        33        21  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.346        58        29  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.737        15        44  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.275        23         7  0/1 NaN
# KRAS_p.G12D  chr12  25245350   C   T  0.761        54       173  0/1 NaN
#
#             VariantType  ... Funseq2Score PharmgkbID DidaID DidaName  \
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# ...                 ...  ...          ...        ...    ...      ...
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
# KRAS_p.G12D         SNP  ...          4.0        NaN    NaN      NaN
#
#             GwasDisease GwasPmID GTexGene   DepMap_ID EntrezGeneID  \
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000967       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000955       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000982       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000270       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000155       3845.0
# ...                 ...      ...      ...         ...          ...
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000307       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000542       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000114       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-000736       3845.0
# KRAS_p.G12D         NaN      NaN      NaN  ACH-001862       3845.0
#
#             MutationType
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# ...                  ...
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
# KRAS_p.G12D  KRAS_p.G12D
#
# [66 rows x 57 columns]

# %%
### Copy number of genes in different cell lines

### Gene-level copy number data that is log2 transformed with a pseudo-count of 1; log2(CN ratio + 1)

df_cn = pd.read_csv('OmicsCNGene.csv',index_col=0)

# %%
df_cn
# Out:
#             DDX11L1 (84771)  WASH7P (653635)  MIR6859-1 (102466751)  \
# ACH-000759         1.675758         1.675758               1.675758
# ACH-000681         0.775472         0.775472               0.775472
# ACH-000769         2.988233         2.988233               2.988233
# ACH-002291         0.790799         0.790799               0.790799
# ACH-000853         1.083618         1.083618               1.083618
# ...                     ...              ...                    ...
# ACH-000185         1.000350         1.000350               1.000350
# ACH-001044         0.542823         0.542823               0.542823
# ACH-000494         1.005360         1.005360               1.005360
# ACH-001087         1.038911         1.038911               1.038911
# ACH-000526         0.737911         0.737911               0.737911
#
#             MIR1302-2 (100302278)  FAM138A (645520)  OR4F5 (79501)  \
# ACH-000759               1.675758          1.675758       1.675758
# ACH-000681               0.775472          0.775472       0.775472
# ACH-000769               2.988233          2.988233       2.988233
# ACH-002291               0.790799          0.790799       0.790799
# ACH-000853               1.083618          1.083618       1.083618
# ...                           ...               ...            ...
# ACH-000185               1.000350          1.000350       1.000350
# ACH-001044               0.542823          0.542823       0.542823
# ACH-000494               1.005360          1.005360       1.005360
# ACH-001087               1.038911          1.038911       1.038911
# ACH-000526               0.737911          0.737911       0.906565
#
#             WASH9P (102723897)  MIR6859-2 (102465909)  OR4F29 (729759)  \
# ACH-000759            1.675758               1.675758         1.675758
# ACH-000681            0.775472               0.775472         0.775472
# ACH-000769            0.831376               0.831376         0.831376
# ACH-002291            0.790799               0.790799         0.790799
# ACH-000853            1.083618               1.083618         1.083618
# ...                        ...                    ...              ...
# ACH-000185            1.000350               1.000350         1.000350
# ACH-001044            1.043950               1.043950         1.043950
# ACH-000494            1.005360               1.005360         1.005360
# ACH-001087            1.038911               1.038911         1.038911
# ACH-000526            1.004657               1.004657         1.004657
#
#             AL669831.3 (101928626)  ...  BPY2C (442868)  TTTY4C (474150)  \
# ACH-000759                1.285546  ...             NaN              NaN
# ACH-000681                0.775472  ...             NaN              NaN
# ACH-000769                0.831376  ...             NaN              NaN
# ACH-002291                0.790799  ...        0.450553         0.450553
# ACH-000853                1.083618  ...        0.637717         0.637717
# ...                            ...  ...             ...              ...
# ACH-000185                1.000350  ...        0.047106         0.047106
# ACH-001044                1.043950  ...        0.711068         0.711068
# ACH-000494                1.005360  ...        0.078468         0.078468
# ACH-001087                1.038911  ...        0.218842         0.218842
# ACH-000526                1.004657  ...        0.034263         0.034263
#
#             CSPG4P1Y (114758)  CDY1 (9085)  TTTY3 (114760)  SNORD38B (94163)  \
# ACH-000759                NaN          NaN             NaN               NaN
# ACH-000681                NaN          NaN             NaN               NaN
# ACH-000769                NaN          NaN             NaN               NaN
# ACH-002291           0.450553     0.450553        0.450553               NaN
# ACH-000853           0.637717     0.637717        0.637717               NaN
# ...                       ...          ...             ...               ...
# ACH-000185           0.155943     0.089672        0.089672          1.000950
# ACH-001044           0.711068     0.711068        0.711068          1.057242
# ACH-000494           0.140482     0.140482        0.140482          1.008726
# ACH-001087           0.218842     0.218842        0.218842          1.045753
# ACH-000526           0.087557     0.087557        0.087557          1.005661
#
#             SCARNA4 (677771)  SNORA50A (677830)  SNORD3D (780854)  \
# ACH-000759               NaN                NaN               NaN
# ACH-000681               NaN                NaN               NaN
# ACH-000769               NaN                NaN               NaN
# ACH-002291               NaN                NaN               NaN
# ACH-000853               NaN                NaN               NaN
# ...                      ...                ...               ...
# ACH-000185          1.040914           1.003705          0.995258
# ACH-001044          1.067719           0.852284          0.994610
# ACH-000494          0.990482           1.003003          1.002252
# ACH-001087          1.025980           1.090470          1.036552
# ACH-000526          1.001651           0.994461          0.536799
#
#             POLR2J3 (548644)
# ACH-000759               NaN
# ACH-000681               NaN
# ACH-000769               NaN
# ACH-002291               NaN
# ACH-000853               NaN
# ...                      ...
# ACH-000185          1.008223
# ACH-001044          1.258299
# ACH-000494          1.005009
# ACH-001087          1.074846
# ACH-000526          1.012655
#
# [1775 rows x 25368 columns]

# %%
import seaborn as sns

sns.distplot(df_cn.loc['ACH-000681',:])
# Out:
# /Users/whe3/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ACH-000681', ylabel='Density'>
